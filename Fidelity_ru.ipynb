# %% [markdown]
# # Ошибка восстановления карт ФЛ
#
# Средняя ошибка `1 - косинусная фиделити` и стандартное отклонение по всем картам из `CD_HM_dataset`.

# %%
import matplotlib.pyplot as plt

from fl_reconstruction_utils import (
    BASIS_LABELS_EN,
    BASIS_LABELS_RU,
    RECONSTRUCTION_BASIS_TYPES,
    RESULTS_DIR,
    compute_fidelity_summary,
    load_fidelity_summary,
    plot_fidelity_summary,
)

# %%
RESULTS_DIR.mkdir(parents=True, exist_ok=True)
CACHE_PATH = RESULTS_DIR / "fidelity_summary.json"

#compute_fidelity_summary(
#    basis_types=RECONSTRUCTION_BASIS_TYPES,
#    cache_path=CACHE_PATH,
#    use_cache=True,
#)

# %%
summary = load_fidelity_summary(CACHE_PATH)
summary
# Out:
# {'legendre': [{'order': 0,
#    'n_coefficients': 1,
#    'mean': 0.577053673375879,
#    'std': 0.050232095846216386},
#   {'order': 1,
#    'n_coefficients': 3,
#    'mean': 0.6213479661929276,
#    'std': 0.04721670629554087},
#   {'order': 2,
#    'n_coefficients': 6,
#    'mean': 0.8013331143824722,
#    'std': 0.0655543640530792},
#   {'order': 3,
#    'n_coefficients': 10,
#    'mean': 0.844128867867777,
#    'std': 0.06839598998864144},
#   {'order': 4,
#    'n_coefficients': 15,
#    'mean': 0.9045689856515817,
#    'std': 0.06961180404178031},
#   {'order': 5,
#    'n_coefficients': 21,
#    'mean': 0.9249057555768719,
#    'std': 0.07028371047357154},
#   {'order': 6,
#    'n_coefficients': 28,
#    'mean': 0.9365479504283909,
#    'std': 0.06900971378321592},
#   {'order': 7,
#    'n_coefficients': 36,
#    'mean': 0.9485281752479076,
#    'std': 0.06563757177206703},
#   {'order': 8,
#    'n_coefficients': 45,
#    'mean': 0.9488274277862557,
# ...

# %%
labels = {
    "title": "Ошибка восстановления карт ФЛ",
    "x": "Количество коэффициентов разложения",
    "y": "Косинусная метрика",
}

fig = plot_fidelity_summary(
    summary,
    labels=labels,
    basis_labels=BASIS_LABELS_RU,
)
fig.savefig(RESULTS_DIR / "fidelity_ru.png", dpi=300, bbox_inches="tight")
plt.show()
